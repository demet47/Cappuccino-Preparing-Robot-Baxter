# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "" # Delete above if you want to use GPU
import tensorflow as tf
import keras
from keras.layers import Softmax,Input,TimeDistributed,Dense,Average,GlobalAveragePooling1D,Concatenate,Lambda,RepeatVector
from keras.models import Model, load_model
from keras.optimizers import Adam
from keras.utils import plot_model
import numpy as np
import matplotlib.pyplot as plt
import math
import time
import pylab as pl
from IPython import display
from IPython.core.display import HTML
from IPython.core.display import display as html_width
import tensorflow_probability as tfp
html_width(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Generating example demonstration:
# These demonstrations are used in the first experiment of the <b>Conditional Neural Movement Primitives (RSS 2019) by Yunus Seker, Mert Imre, Justus Piater and Emre Ugur</b>
#
# This experiment does not involve external parameters.

# %%
def dist_generator(d, x, param, noise = 0):
    f = (math.exp(-x**2/(2.*param[0]**2))/(math.sqrt(2*math.pi)*param[0]))+param[1]
    return f+(noise*(np.random.rand()-0.5)/100.)

def generate_demonstrations(time_len = 200, params = None, title = None):
    fig = plt.figure(figsize=(5,5))
    x = np.linspace(-0.5,0.5,time_len)
    times = np.zeros((params.shape[0],time_len,1))
    times[:] = x.reshape((1,time_len,1))+0.5
    values = np.zeros((params.shape[0],time_len,1))
    for d in range(params.shape[0]):
            for i in range(time_len):
                values[d,i] = dist_generator(d,x[i],params[d])
            plt.plot(times[d], values[d])
    plt.title(title+' Demonstrations')
    plt.ylabel('Starting Position')
    plt.show()
    return times, values

X, Y = generate_demonstrations(time_len=200, params=np.array([[0.6,-0.1],[0.5,-0.23],[0.4,-0.43],[-0.6,0.1],[-0.5,0.23],[-0.4,0.43]]), title='Training')
v_X, v_Y = generate_demonstrations(time_len=200, params=np.array([[0.55,-0.155],[0.45,-0.32],[-0.45,0.32],[-0.55,0.155]]), title='Validation')

#Y = np.pad(Y, ((0, 0), (0, 0), (0, 2)), mode='constant')
        
print('training X ', X.shape)
print('training Y ',Y.shape)
print('validation X ', v_X.shape)
print('validation Y ',v_Y.shape)
np.save('training_X',X)
np.save('training_Y',Y)
np.save('validation_X',v_X)
np.save('validation_Y',v_Y)
# Out:
# training X  (6, 200, 1)
# training Y  (6, 200, 1)
# validation X  (4, 200, 1)
# validation Y  (4, 200, 1)

# %%
def interpolateJointData(trajectory, num_of_steps_expected):
    """
    new_trajectory = []
    l = len(trajectory)
    print(len(trajectory))
    size_to_add = num_of_steps_expected - l
    if size_to_add == 0:
        return trajectory
    mod = l % size_to_add
    jump_len =  (l - mod) // size_to_add
    
    for index in range(0, size_to_add):
        new_trajectory.extend(trajectory[index*jump_len: index*(jump_len+1)])
        new_trajectory.append([sum(x)/2 for x in zip(trajectory[index*(jump_len+1)], trajectory[index*(jump_len+1) + 1])])
    new_trajectory.extend(trajectory[-1] * mod)
    return new_trajectory
    """
    trajectory = trajectory.tolist()
    return trajectory.extend(trajectory[-1] * (num_of_steps_expected - len(trajectory)))

# %% [markdown]
# ## Loading model inputs
# <b>Input Requirements</b>:
#
# * <b>obs_max</b>: Hyperparameter that decides to the maximum number of observations CNMP uses. In this experiment, it is set to 5
# * <b>d_N</b>: Number of demonstrations (in our case, 5)
#
# * <b>d_x</b>: X vector feature dim (NOTE THAT: external parameters are assumed to be inside of the X vector, concatenated to time value. This experiment uses joint data which is 7 data per side (7*2 = 14 sized) as external parameters so d_x = 14)
#
# * <b>d_y</b>: Y vector feature dim
#
# * <b>time_len</b>: length of the demonstrations, if all demonstrations does not have same length, use array and edit methods using time_len, or preprocess your data to interpolate into same time length (custom function used to extend the trajectory called interpolateJointData(trajectory, num_of_steps_expected))
#
# * <b>X</b>: shape=(d_N,time_len,d_x) --- time (and external parameter) values for each timestep for ith demonstration. d_x = 1+d_external_parameters
#
# * <b>Y</b>: shape=(d_N,time_len,d_y) --- corresponding values of f(X) for ith demonstration
#
# * <b>obs_mlp_layers</b>: Hidden neuron numbers of the dense layers inside of the Observation multi layer perceptron. Layer numbers can adapt to the list size. Last layer is always Linear, others are ReLU activated.
#
# * <b>decoder_layers</b>: Hidden neuron numbers of the dense layers inside of the Decoder multi layer perceptron. Layer numbers can adapt to the list size. Last layer size is always 2*d_y and activation is Linear, others are ReLU activated.

# %%
#Loading demonstrations and necessary variables
X0, X1, X2, X3, X4 = (np.genfromtxt('./initial_data/salimdemet1_0.csv', delimiter=','), np.genfromtxt('./initial_data/salimdemet1_1.csv', delimiter=','), 
                      np.genfromtxt('./initial_data/salimdemet1_2.csv', delimiter=','), np.genfromtxt('./initial_data/salimdemet1_3.csv', delimiter=','),
                      np.genfromtxt('./initial_data/salimdemet1_4.csv', delimiter=','))

X = [X0, X1, X2, X3, X4] #list of np arrays
length = len(max(X, key=len))
X = np.array([interpolateJointData(element, length) for element in X])


Y0, Y1, Y2, Y3, Y4 = (np.genfromtxt('./initial_data/salimdemet2_0.csv', delimiter=','), np.genfromtxt('./initial_data/salimdemet2_1.csv', delimiter=','), 
                      np.genfromtxt('./initial_data/salimdemet2_2.csv', delimiter=','), np.genfromtxt('./initial_data/salimdemet2_3.csv', delimiter=','),
                      np.genfromtxt('./initial_data/salimdemet2_4.csv', delimiter=','))
Y = [Y0, Y1, Y2, Y3, Y4]
length = len(max(Y, key=len))
Y = np.array([interpolateJointData(element, length) for element in Y])


VX_0, VX_1, VX_2, VX_3, VX_4 = (np.genfromtxt('./initial_data/salimdemet1_5.csv', delimiter=','), np.genfromtxt('./initial_data/salimdemet1_6.csv', delimiter=','),
                          np.genfromtxt('./initial_data/salimdemet1_7.csv', delimiter=','), X3, X0)
v_X = [VX_0, VX_1, VX_2, VX_3, VX_4]
length = len(max(v_X, key=len))
v_X = np.array([interpolateJointData(element, length) for element in v_X])

v_Y = np.array([Y[3], Y[1], Y[4], Y[2], Y[0]])

obs_max = 5  
d_N = X.shape[0] 
d_x , d_y = (X.shape[-1] , Y.shape[-1])

# %%
Y
# Out:
# array([None, None, None, None, None], dtype=object)

# %% [markdown]
# # Conditional Neural Movement Primitives

# %% [markdown]
# ### <b>get_train_sample()</b>:
# * Selects a random observation number, n
# * Selects a random demonstration id, d
# * Permutes demonstration d, so the first n data can be observation. Selects (n+1)th data to be the target point
# * Returns observations and target_X as inputs to the model to predict target_Y

# %%
def get_train_sample():
    n = np.random.randint(0,obs_max)+1
    d = np.random.randint(0, d_N)
    observation = np.zeros((1,n,d_x+d_y)) 
    target_X = np.zeros((1,1,d_x))
    target_Y = np.zeros((1,1,d_y*2))
    perm = np.random.permutation(time_len)
    observation[0,:n,:d_x] = X[d,perm[:n]]
    observation[0,:n,d_x:d_x+d_y] = Y[d,perm[:n]]
    target_X[0,0] = X[d,perm[n]]
    target_Y[0,0,:d_y] = Y[d,perm[n]]
    return [observation,target_X], target_Y

# %% [markdown]
# ### <b>predict_model()</b>:
# * Predicts whole trajectory according to the given observation batch
# * <b>observation</b>: observation points as a batch.
#   * Dimension must be -> (1, obs_n, d_x+d_y) where obs_n is the number of observations for this prediction
# * <b>target_X</b>: target X points as a batch. Model can predict one, multi, partial or whole trajectory/points as long as input is shaped as a batch
#   * Dimension must be -> (1, target_n, d_x) where target_n is the number of points to predict
#   * For whole trajectory give all X points through time length as a batch (for ex. the first demonstration = X[0].reshape=(1,time_len,d_x)
# * <b>prediction</b>: Output that holds predicted means and standart deviations for each time point in the X. Later splitted into <b>predicted_Y</b> and <b>predicted_std</b>
# * <b>plot</b>: if True, plots demonstrations and predicted distribution
# * Returns predicted means and stds

# %%
def predict_model(observation, target_X, plot = True):
    predicted_Y = np.zeros((time_len,d_y))
    predicted_std = np.zeros((time_len,d_y))
    prediction = model.predict([observation,target_X])[0] 
    predicted_Y = prediction[:,:d_y]
    predicted_std = np.log(1+np.exp(prediction[:,d_y:]))
    if plot: # We highly recommend that you customize your own plot function, but you can use this function as default
        for i in range(d_y): #for every feature in Y vector we are plotting training data and its prediction
            fig = plt.figure(figsize=(5,5))
            for j in range(d_N):
                plt.plot(X[j,:,0],Y[j,:,i]) # assuming X[j,:,0] is time
            plt.plot(X[j,:,0],predicted_Y[:,i],color='black')
            plt.errorbar(X[j,:,0],predicted_Y[:,i],yerr=predicted_std[:,i],color = 'black',alpha=0.4)
            plt.scatter(observation[0,:,0],observation[0,:,d_x+i],marker="X",color='black')
            plt.show()  
    return predicted_Y, predicted_std

# %% [markdown]
# ### custom_loss():
# * Calculates log probability of the true value of the target point according to the multivariate Gaussian constructed by predicted means and stds
# * Returns minus of that value

# %%
def custom_loss(y_true, y_predicted):
    mean, log_sigma = tf.split(y_predicted, 2, axis=-1)
    y_true_value, temp =tf.split(y_true,2,axis=-1)
    sigma = tf.nn.softplus(log_sigma)
    dist = tfp.distributions.MultivariateNormalDiag(loc=mean, scale_diag=sigma)
    loss = -tf.reduce_mean(dist.log_prob(y_true_value))
    return loss

# %% [markdown]
# ### MLP():
#
# * Constructs a multilayer perceptron according to the given input dimension and layer sizes.
# * <b>input_dim</b>: dimension of the input feature vector
# * <b>layers</b>: Constructs a dense layer for each number in the list. Layer numbers are flexible to list size. Except for the last layer, all layers are ReLU activated.
#   * ex: (2,[128,128,128]) Constructs a multi layer perceptron with each dense layer's neuron sizes correspond to (2->128->128->128) from input to output
#   * ex: (4,[128,4]) Constructs a multi layer perceptron with each dense layer's neuron sizes correspond to (4->128->4) from input to output
# * <b>parallel_input</b>:
#   * if <b>False</b>, MLP acts as classical fully connected MLP. Output is a single result.
#   * if <b>True</b>, MLP acts as a single parameter-sharing network. Every tuple in the input batch passes through MLP paralelly, independently from each other. Output is a batch which every row is the result of the corresponding tuple from the input batch passing through the parameter-sharing network.
#   * <b>TLDR;</b> use parallel input for encoding observations into representations, and fully connected MLP for every any other dense networks.

# %%
def MLP(input_dim, layers, name="mlp", parallel_inputs=False):
    input_layer = Input(shape=(None, input_dim),name=name+'_input')
    for i in range(len(layers)-1):
        hidden = TimeDistributed(Dense(layers[i], activation='relu'), name=name+'_'+str(i))(input_layer if i == 0 else hidden) if parallel_inputs else Dense(layers[i], activation='relu', name=name+'_'+str(i))(input_layer if i == 0 else hidden)
    hidden = TimeDistributed(Dense(layers[-1]), name=name+'_output')(hidden) if parallel_inputs else Dense(layers[-1], name=name+'_output')(hidden)
    return Model(input_layer, hidden, name=name)

# %% [markdown]
# ## CNMP model:

# %% [markdown]
# <p>
# As proposed in the paper, the model is created. Layers can be tracked from figure below:
# <br>
# <img src="CNP.png" width=500 align="left">
# </p>

# %%
observation_layer = Input(shape=(None,d_x+d_y), name="observation") # (x_o,y_o) tuples
target_X_layer = Input(shape=(None,d_x), name="target") # x_q

ObsMLP = MLP(d_x+d_y, obs_mlp_layers, name='obs_mlp', parallel_inputs=True) # Network E
obs_representations = ObsMLP(observation_layer) # r_i
general_representation = GlobalAveragePooling1D()(obs_representations) # r
general_representation = Lambda(lambda x: tf.keras.backend.repeat(x[0],tf.shape(x[1])[1]), name='Repeat')([general_representation,target_X_layer]) # r in batch form (same)

merged_layer = Concatenate(axis=2, name='merged')([general_representation,target_X_layer]) # (r,x_q) tuple
Decoder = MLP(d_x+obs_mlp_layers[-1], decoder_layers, name = 'decoder_mlp', parallel_inputs=False) # Network Q
output = Decoder(merged_layer) # (mean_q, std_q)

model = Model([observation_layer, target_X_layer],output)
model.compile(optimizer = Adam(learning_rate= 1e-4),loss=custom_loss)
model.summary()

plot_model(model)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  observation (InputLayer)       [(None, None, 2)]    0           []
#
#  obs_mlp (Functional)           (None, None, 128)    33408       ['observation[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 128)         0           ['obs_mlp[0][0]']
#  obalAveragePooling1D)
#
#  target (InputLayer)            [(None, None, 1)]    0           []
#
#  Repeat (Lambda)                (None, None, 128)    0           ['global_average_pooling1d_1[0][0
#                                                                  ]',
#                                                                   'target[0][0]']
#
#  merged (Concatenate)           (None, None, 129)    0           ['Repeat[0][0]',
#                                                                   'target[0][0]']
#
#  decoder_mlp (Functional)       (None, None, 2)      33410       ['merged[0][0]']
#
# ==================================================================================================
# Total params: 66,818
# Trainable params: 66,818
# Non-trainable params: 0
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### generator():
#
# * Generates data using get_train_sample function during training

# %%
def generator():
    while True:
        inp,out = get_train_sample()
        yield (inp, out)

# %% [markdown]
# ### CNMP_Callback:
#
# * CNMP_Callback is a customizable class that manages the CNMP training process.
# * <b>on_train_begin()</b>: Initializes the training process
#   * <b>step</b>: training step counter
#   * <b>losses</b>: holds the training losses for every loss_checkpoint
#   * <b>smooth_losses</b>: holds the means of losses[] for every plot_checkpoint
#   * <b>loss_checkpoint</b>: hyperparameter for loss recording
#   * <b>plot_checkpoint</b>: hyperparameter for loss smoothing and on-train example plotting
#   * <b>validation_checkpoint</b>: hyperparameter for validation checking to record best model
# * <b>on_batch_end()</b>:
#   * End of every training iteration, step counter increases
#   * Customized checkpoints are handled if step counter gets to the corresponding checkpoint

# %%
class CNMP_Callback(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.smooth_losses = [0]
        self.losses = []
        self.step = 0
        self.loss_checkpoint = 1000
        self.plot_checkpoint = 10000
        self.validation_checkpoint = 100
        self.validation_error = 9999999
        return

    def on_batch_end(self, batch, logs={}):
        if self.step % self.validation_checkpoint == 0:
            ### Here, you should customize our own validation function according to your data and save your best model ###
            current_error = 0
            for i in range(v_X.shape[0]):
                # predicting whole trajectory by using the first time step of the ith validation trajectory as given observation
                predicted_Y,predicted_std = predict_model(np.concatenate((v_X[i,0],v_Y[i,0])).reshape(1,1,d_x+d_y), v_X[i].reshape(1,time_len,d_x), plot= False)
                current_error += np.mean((predicted_Y - v_Y[i,:])**2) / v_X.shape[0]
            if current_error < self.validation_error:
                self.validation_error = current_error
                model.save('cnmp_best_validation.h5')
                print(' New validation best. Error is ', current_error)
            ### If you are not using validation, please note that every large-enough nn model will eventually overfit to the input data ###
            
        if self.step % self.loss_checkpoint == 0:
            self.losses.append(logs.get('loss'))
            self.smooth_losses[-1] += logs.get('loss')/(self.plot_checkpoint/self.loss_checkpoint)
            
        if self.step % self.plot_checkpoint == 0:
            print(self.step)
            #clearing output cell
            display.clear_output(wait=True)
            display.display(pl.gcf())
            
            #plotting training and smoothed losses
            plt.figure(figsize=(15,5))
            plt.subplot(121)
            plt.title('Train Loss')
            plt.plot(range(len(self.losses)),self.losses)
            plt.subplot(122)
            plt.title('Train Loss (Smoothed)')
            plt.plot(range(len(self.smooth_losses)),self.smooth_losses)
            plt.show()
            
            #plotting on-train examples by user given observations
            for i in range(v_X.shape[0]):
                #for each validation trajectory, predicting and plotting whole trajectories by using the first time steps as given observations. 
                predict_model(np.concatenate((v_X[i,0],v_Y[i,0])).reshape(1,1,d_x+d_y), v_X[i].reshape(1,time_len,d_x))
            
            if self.step!=0:
                self.smooth_losses.append(0)
            
        self.step += 1
        return

# %% [markdown]
# ### Starting the training

# %%
max_training_step = 1000000
model.fit_generator(generator(), steps_per_epoch=max_training_step, epochs=1, verbose=1, callbacks=[CNMP_Callback()])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/stepETA: 1:41 - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/stepETA: 1:40 - loss: -3.31
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 1:39 - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:38 - loss: -3.31
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/stepETA: 1:37 - loss: -3.31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1:36 - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/stepETA: 1:35 - loss: -3.31
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:34 - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:33 - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:32 - loss: -3.31
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/stepETA: 1:31 - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 1:30 - loss: -3.31
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 1:29 - loss: -3.31
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/stepETA: 1:28 - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/stepETA: 1:26 - loss: -3.31
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/stepETA: 1:25 - loss: -3.31
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/stepETA: 1:24 - loss: -3.31
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 1:23 - loss: -3.31
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1:22 - loss: -3.31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1:21 - loss: -3.31
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:20 - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 1:19 - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/stepETA: 1:18 - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/stepETA: 1:17 - loss: -3.31
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/stepETA: 1:16 - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 1:15 - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/stepETA: 1:14 - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1:13 - loss: -3.31
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/stepETA: 1:12 - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:11 - loss: -3.31
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/stepETA: 1:10 - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 1:09 - loss: -3.31
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1:08 - loss: -3.31
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 32ms/stepETA: 1:07 - loss: -3.31
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 56ms/stepETA: 1:06 - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/stepETA: 1:05 - loss: -3.31
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/stepETA: 1:04 - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/stepETA: 1:03 - loss: -3.31
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/stepETA: 1:02 - loss: -3.31
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 54ms/stepETA: 1:01 - loss: -3.31
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1:00 - loss: -3.31
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 36ms/stepETA: 59s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 54ms/stepETA: 58s - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/stepETA: 57s - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 56s - loss: -3.31
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/stepETA: 55s - loss: -3.31
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 54s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/stepETA: 53s - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 53ms/stepETA: 52s - loss: -3.31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/stepETA: 51s - loss: -3.31
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/stepETA: 50s - loss: -3.31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/stepETA: 49s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 48s - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/stepETA: 47s - loss: -3.31
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/stepETA: 46s - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 54ms/stepETA: 45s - loss: -3.31
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/stepETA: 44s - loss: -3.31
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/stepETA: 42s - loss: -3.31
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 69ms/stepETA: 41s - loss: -3.31
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 40s - loss: -3.31
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/stepETA: 39s - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/stepETA: 38s - loss: -3.31
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/stepETA: 37s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 36s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 35s - loss: -3.31
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 50ms/stepETA: 34s - loss: -3.31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 33s - loss: -3.31
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 32s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/stepETA: 31s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 30s - loss: -3.31
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/stepETA: 29s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 28s - loss: -3.31
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/stepETA: 27s - loss: -3.31
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/stepETA: 26s - loss: -3.31
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/stepETA: 25s - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/stepETA: 24s - loss: -3.31
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/stepETA: 23s - loss: -3.31
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 22s - loss: -3.31
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/stepETA: 21s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/stepETA: 20s - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/stepETA: 19s - loss: -3.31
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 18s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 17s - loss: -3.31
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 16s - loss: -3.31
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/stepETA: 15s - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 53ms/stepETA: 14s - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/stepETA: 13s - loss: -3.31
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/stepETA: 12s - loss: -3.31
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/stepETA: 11s - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/stepETA: 10s - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/stepETA: 9s - loss: -3.31
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/stepETA: 8s - loss: -3.31
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/stepETA: 7s - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/stepETA: 6s - loss: -3.31
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/stepETA: 5s - loss: -3.31
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/stepETA: 4s - loss: -3.31
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 3s - loss: -3.31
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/stepETA: 2s - loss: -3.31
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 34ms/stepETA: 1s - loss: -3.31
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1000000/1000000 [==============================] - 10234s 10ms/step - loss: -3.3193

# %%
Y = np.pad(Y, ((0, 0), (0, 0), (0, 2)), mode='constant')

# %% [markdown]
# ### Loading the Best Model

# %%
import keras.losses
keras.losses.custom_loss = custom_loss

model = load_model('cnmp_best_validation.h5', custom_objects={ 'tf':tf })
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27096\3611128207.py in <module>
#       1 import keras.losses
#       2 keras.losses.custom_loss = custom_loss
# ----> 3 model = load_model('cnmp_best_validation.h5', custom_objects={ 'tf':tf })
#
# c:\users\dmtya\appdata\local\programs\python\python37\lib\site-packages\keras\saving\saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     211     # Legacy case.
#     212     return legacy_sm_saving_lib.load_model(
# --> 213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#     215
#
# c:\users\dmtya\appdata\local\programs\python\python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\users\dmtya\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\lib\io\file_io.py in is_directory_v2(path)
#     701   """
#     702   try:
# --> 703     return _pywrap_file_io.IsDirectory(compat.path_to_bytes(path))
#     704   except errors.OpError:
#     705     return False
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfc in position 32: invalid start byte

# %% [markdown]
# ### Testing the Model

# %%
predicted_Y,predicted_std = predict_model(np.concatenate(([[0.8]],[[-0.38]]), axis=1).reshape(1,-1,d_x+d_y), X[0].reshape(1,time_len,d_x))
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
predicted_Y
# Out:
# array([[-0.03917962],
#        [-0.04637163],
#        [-0.05355494],
#        [-0.06073835],
#        [-0.06792174],
#        [-0.07513011],
#        [-0.08263108],
#        [-0.09013206],
#        [-0.09752902],
#        [-0.10486913],
#        [-0.11233078],
#        [-0.11972529],
#        [-0.12706944],
#        [-0.13441357],
#        [-0.14178932],
#        [-0.14924213],
#        [-0.15669492],
#        [-0.16416411],
#        [-0.17193651],
#        [-0.17970899],
#        [-0.1874814 ],
#        [-0.19525382],
#        [-0.2030263 ],
#        [-0.2104131 ],
#        [-0.21770498],
#        [-0.22499686],
#        [-0.23228873],
#        [-0.23958054],
#        [-0.24687245],
#        [-0.2541643 ],
#        [-0.26145622],
#        [-0.26874804],
#        [-0.27603996],
#        [-0.28333178],
#        [-0.29062366],
#        [-0.29791555],
#        [-0.30520192],
#        [-0.31248587],
#        [-0.31976986],
#        [-0.3270538 ],
#        [-0.33407024],
#        [-0.3409491 ],
#        [-0.3478279 ],
#        [-0.35431135],
#        [-0.36077294],
#        [-0.3669292 ],
#        [-0.3731031 ],
#        [-0.3792769 ],
#        [-0.38545084],
#        [-0.39162472],
#        [-0.39779857],
#        [-0.40397242],
#        [-0.4101207 ],
#        [-0.4161867 ],
#        [-0.4218812 ],
#        [-0.42718574],
#        [-0.4324529 ],
#        [-0.43766895],
#        [-0.44288513],
#        [-0.44810116],
#        [-0.45331725],
#        [-0.45853338],
#        [-0.4637495 ],
#        [-0.4689656 ],
#        [-0.4741026 ],
#        [-0.47890136],
#        [-0.48370525],
#        [-0.48832846],
#        [-0.4926236 ],
#        [-0.49691865],
#        [-0.50121385],
#        [-0.50550896],
#        [-0.509804  ],
#        [-0.5139692 ],
#        [-0.5175894 ],
#        [-0.5212121 ],
#        [-0.52483475],
#        [-0.52845746],
#        [-0.5320801 ],
#        [-0.53570276],
#        [-0.5393254 ],
#        [-0.5426944 ],
#        [-0.5450057 ],
#        [-0.5466586 ],
#        [-0.54828554],
#        [-0.5499124 ],
#        [-0.5515393 ],
#        [-0.5531662 ],
#        [-0.5547932 ],
#        [-0.5562867 ],
#        [-0.5572455 ],
#        [-0.5582044 ],
#        [-0.5591633 ],
#        [-0.56012213],
#        [-0.561081  ],
#        [-0.5618561 ],
#        [-0.56225544],
#        [-0.562398  ],
#        [-0.5623713 ],
#        [-0.56234485],
#        [-0.56231815],
#        [-0.5622915 ],
#        [-0.5622056 ],
#        [-0.5619658 ],
#        [-0.5610493 ],
#        [-0.5600099 ],
#        [-0.55897045],
#        [-0.55793107],
#        [-0.5568916 ],
#        [-0.5558522 ],
#        [-0.5548127 ],
#        [-0.55377334],
#        [-0.55273384],
#        [-0.5516704 ],
#        [-0.5501603 ],
#        [-0.54827064],
#        [-0.5463271 ],
#        [-0.54388976],
#        [-0.5409613 ],
#        [-0.53787357],
#        [-0.5347857 ],
#        [-0.53169787],
#        [-0.52844834],
#        [-0.52477676],
#        [-0.5210619 ],
#        [-0.51734716],
#        [-0.5134968 ],
#        [-0.50959194],
#        [-0.505687  ],
#        [-0.50178206],
#        [-0.49737772],
#        [-0.49247023],
#        [-0.4875628 ],
#        [-0.48265532],
#        [-0.4777479 ],
#        [-0.47284043],
#        [-0.4679329 ],
#        [-0.46302554],
#        [-0.45811805],
#        [-0.45321068],
#        [-0.44830313],
#        [-0.44339564],
#        [-0.43848822],
#        [-0.4335808 ],
#        [-0.42867333],
#        [-0.42376587],
#        [-0.41885844],
#        [-0.4132063 ],
#        [-0.40678594],
#        [-0.40029582],
#        [-0.3936681 ],
#        [-0.38685507],
#        [-0.38004184],
#        [-0.37322816],
#        [-0.36641455],
#        [-0.35949802],
#        [-0.35246864],
#        [-0.34534737],
#        [-0.3382261 ],
#        [-0.3311049 ],
#        [-0.32398364],
#        [-0.31686234],
#        [-0.30971333],
#        [-0.30255237],
#        [-0.29539153],
#        [-0.28823057],
#        [-0.28106976],
#        [-0.27390975],
#        [-0.26674965],
#        [-0.25958958],
#        [-0.25242946],
#        [-0.24526936],
#        [-0.23810935],
#        [-0.23089296],
#        [-0.22355515],
#        [-0.21621744],
#        [-0.20887959],
#        [-0.20154092],
#        [-0.19410759],
#        [-0.18667419],
#        [-0.17924099],
#        [-0.17180768],
#        [-0.16437446],
#        [-0.15694112],
#        [-0.14950775],
#        [-0.14206317],
#        [-0.13460106],
#        [-0.12713891],
#        [-0.11968759],
#        [-0.11234967],
#        [-0.10498071],
#        [-0.09760791],
#        [-0.09023505],
#        [-0.08297588],
#        [-0.07577465],
#        [-0.06857341],
#        [-0.06104346],
#        [-0.05346416],
#        [-0.04588488],
#        [-0.03830554]], dtype=float32)
